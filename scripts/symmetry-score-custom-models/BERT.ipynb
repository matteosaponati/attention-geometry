# %%
import pickle
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '../../_data/pascal-data/symmetric-attention-from-scratch-clean/'

# %%
def get_interpolation(data):

    data = data.to_numpy()
    x = np.arange(data.size)
    data = np.interp(x, x[~np.isnan(data)], 
                                  data[~np.isnan(data)])

    return data

def save_data(data):

    list = [get_interpolation(data['_step']),
            get_interpolation(data['train/global_step']),
            get_interpolation(data['Mean Symmetry']),
            get_interpolation(data['Min Symmetry']),
            get_interpolation(data['Max Symmetry']),
            get_interpolation(data['Median Symmetry']),
            get_interpolation(data['Variance Symmetry']),
            get_interpolation(data['Layer 0/Head 0 Symmetry']),
            get_interpolation(data['Layer 0/Head 1 Symmetry']),
            get_interpolation(data['Layer 0/Head 2 Symmetry']),
            get_interpolation(data['Layer 0/Head 3 Symmetry']),
            get_interpolation(data['Layer 0/Head 4 Symmetry']),
            get_interpolation(data['Layer 0/Head 5 Symmetry']),
            get_interpolation(data['Layer 0/Head 6 Symmetry']),
            get_interpolation(data['Layer 0/Head 7 Symmetry']),
            get_interpolation(data['Layer 0/Head 8 Symmetry']),
            get_interpolation(data['Layer 0/Head 9 Symmetry']),
            get_interpolation(data['Layer 0/Head 10 Symmetry']),
            get_interpolation(data['Layer 0/Head 11 Symmetry']),
            get_interpolation(data['Layer 1/Head 0 Symmetry']),
            get_interpolation(data['Layer 1/Head 1 Symmetry']),
            get_interpolation(data['Layer 1/Head 2 Symmetry']),
            get_interpolation(data['Layer 1/Head 3 Symmetry']),
            get_interpolation(data['Layer 1/Head 4 Symmetry']),
            get_interpolation(data['Layer 1/Head 5 Symmetry']),
            get_interpolation(data['Layer 1/Head 6 Symmetry']),
            get_interpolation(data['Layer 1/Head 7 Symmetry']),
            get_interpolation(data['Layer 1/Head 8 Symmetry']),
            get_interpolation(data['Layer 1/Head 9 Symmetry']),
            get_interpolation(data['Layer 1/Head 10 Symmetry']),
            get_interpolation(data['Layer 1/Head 11 Symmetry']),
            get_interpolation(data['Layer 2/Head 0 Symmetry']),
            get_interpolation(data['Layer 2/Head 1 Symmetry']),
            get_interpolation(data['Layer 2/Head 2 Symmetry']),
            get_interpolation(data['Layer 2/Head 3 Symmetry']),
            get_interpolation(data['Layer 2/Head 4 Symmetry']),
            get_interpolation(data['Layer 2/Head 5 Symmetry']),
            get_interpolation(data['Layer 2/Head 6 Symmetry']),
            get_interpolation(data['Layer 2/Head 7 Symmetry']),
            get_interpolation(data['Layer 2/Head 8 Symmetry']),
            get_interpolation(data['Layer 2/Head 9 Symmetry']),
            get_interpolation(data['Layer 2/Head 10 Symmetry']),
            get_interpolation(data['Layer 2/Head 11 Symmetry']),
            get_interpolation(data['Layer 3/Head 0 Symmetry']),
            get_interpolation(data['Layer 3/Head 1 Symmetry']),
            get_interpolation(data['Layer 3/Head 2 Symmetry']),
            get_interpolation(data['Layer 3/Head 3 Symmetry']),
            get_interpolation(data['Layer 3/Head 4 Symmetry']),
            get_interpolation(data['Layer 3/Head 5 Symmetry']),
            get_interpolation(data['Layer 3/Head 6 Symmetry']),
            get_interpolation(data['Layer 3/Head 7 Symmetry']),
            get_interpolation(data['Layer 3/Head 8 Symmetry']),
            get_interpolation(data['Layer 3/Head 9 Symmetry']),
            get_interpolation(data['Layer 3/Head 10 Symmetry']),
            get_interpolation(data['Layer 3/Head 11 Symmetry']),
            get_interpolation(data['Layer 4/Head 0 Symmetry']),
            get_interpolation(data['Layer 4/Head 1 Symmetry']),
            get_interpolation(data['Layer 4/Head 2 Symmetry']),
            get_interpolation(data['Layer 4/Head 3 Symmetry']),
            get_interpolation(data['Layer 4/Head 4 Symmetry']),
            get_interpolation(data['Layer 4/Head 5 Symmetry']),
            get_interpolation(data['Layer 4/Head 6 Symmetry']),
            get_interpolation(data['Layer 4/Head 7 Symmetry']),
            get_interpolation(data['Layer 4/Head 8 Symmetry']),
            get_interpolation(data['Layer 4/Head 9 Symmetry']),
            get_interpolation(data['Layer 4/Head 10 Symmetry']),
            get_interpolation(data['Layer 4/Head 11 Symmetry']),
            get_interpolation(data['Layer 5/Head 0 Symmetry']),
            get_interpolation(data['Layer 5/Head 1 Symmetry']),
            get_interpolation(data['Layer 5/Head 2 Symmetry']),
            get_interpolation(data['Layer 5/Head 3 Symmetry']),
            get_interpolation(data['Layer 5/Head 4 Symmetry']),
            get_interpolation(data['Layer 5/Head 5 Symmetry']),
            get_interpolation(data['Layer 5/Head 6 Symmetry']),
            get_interpolation(data['Layer 5/Head 7 Symmetry']),
            get_interpolation(data['Layer 5/Head 8 Symmetry']),
            get_interpolation(data['Layer 5/Head 9 Symmetry']),
            get_interpolation(data['Layer 5/Head 10 Symmetry']),
            get_interpolation(data['Layer 5/Head 11 Symmetry']),
            get_interpolation(data['Layer 6/Head 0 Symmetry']),
            get_interpolation(data['Layer 6/Head 1 Symmetry']),
            get_interpolation(data['Layer 6/Head 2 Symmetry']),
            get_interpolation(data['Layer 6/Head 3 Symmetry']),
            get_interpolation(data['Layer 6/Head 4 Symmetry']),
            get_interpolation(data['Layer 6/Head 5 Symmetry']),
            get_interpolation(data['Layer 6/Head 6 Symmetry']),
            get_interpolation(data['Layer 6/Head 7 Symmetry']),
            get_interpolation(data['Layer 6/Head 8 Symmetry']),
            get_interpolation(data['Layer 6/Head 9 Symmetry']),
            get_interpolation(data['Layer 6/Head 10 Symmetry']),
            get_interpolation(data['Layer 6/Head 11 Symmetry']),
            get_interpolation(data['Layer 7/Head 0 Symmetry']),
            get_interpolation(data['Layer 7/Head 1 Symmetry']),
            get_interpolation(data['Layer 7/Head 2 Symmetry']),
            get_interpolation(data['Layer 7/Head 3 Symmetry']),
            get_interpolation(data['Layer 7/Head 4 Symmetry']),
            get_interpolation(data['Layer 7/Head 5 Symmetry']),
            get_interpolation(data['Layer 7/Head 6 Symmetry']),
            get_interpolation(data['Layer 7/Head 7 Symmetry']),
            get_interpolation(data['Layer 7/Head 8 Symmetry']),
            get_interpolation(data['Layer 7/Head 9 Symmetry']),
            get_interpolation(data['Layer 7/Head 10 Symmetry']),
            get_interpolation(data['Layer 7/Head 11 Symmetry']),
            get_interpolation(data['Layer 8/Head 0 Symmetry']),
            get_interpolation(data['Layer 8/Head 1 Symmetry']),
            get_interpolation(data['Layer 8/Head 2 Symmetry']),
            get_interpolation(data['Layer 8/Head 3 Symmetry']),
            get_interpolation(data['Layer 8/Head 4 Symmetry']),
            get_interpolation(data['Layer 8/Head 5 Symmetry']),
            get_interpolation(data['Layer 8/Head 6 Symmetry']),
            get_interpolation(data['Layer 8/Head 7 Symmetry']),
            get_interpolation(data['Layer 8/Head 8 Symmetry']),
            get_interpolation(data['Layer 8/Head 9 Symmetry']),
            get_interpolation(data['Layer 8/Head 10 Symmetry']),
            get_interpolation(data['Layer 8/Head 11 Symmetry']),
            get_interpolation(data['Layer 9/Head 0 Symmetry']),
            get_interpolation(data['Layer 9/Head 1 Symmetry']),
            get_interpolation(data['Layer 9/Head 2 Symmetry']),
            get_interpolation(data['Layer 9/Head 3 Symmetry']),
            get_interpolation(data['Layer 9/Head 4 Symmetry']),
            get_interpolation(data['Layer 9/Head 5 Symmetry']),
            get_interpolation(data['Layer 9/Head 6 Symmetry']),
            get_interpolation(data['Layer 9/Head 7 Symmetry']),
            get_interpolation(data['Layer 9/Head 8 Symmetry']),
            get_interpolation(data['Layer 9/Head 9 Symmetry']),
            get_interpolation(data['Layer 9/Head 10 Symmetry']),
            get_interpolation(data['Layer 9/Head 11 Symmetry']),
            get_interpolation(data['Layer 10/Head 0 Symmetry']),
            get_interpolation(data['Layer 10/Head 1 Symmetry']),
            get_interpolation(data['Layer 10/Head 2 Symmetry']),
            get_interpolation(data['Layer 10/Head 3 Symmetry']),
            get_interpolation(data['Layer 10/Head 4 Symmetry']),
            get_interpolation(data['Layer 10/Head 5 Symmetry']),
            get_interpolation(data['Layer 10/Head 6 Symmetry']),
            get_interpolation(data['Layer 10/Head 7 Symmetry']),
            get_interpolation(data['Layer 10/Head 8 Symmetry']),
            get_interpolation(data['Layer 10/Head 9 Symmetry']),
            get_interpolation(data['Layer 10/Head 10 Symmetry']),
            get_interpolation(data['Layer 10/Head 11 Symmetry']),
            get_interpolation(data['Layer 11/Head 0 Symmetry']),
            get_interpolation(data['Layer 11/Head 1 Symmetry']),
            get_interpolation(data['Layer 11/Head 2 Symmetry']),
            get_interpolation(data['Layer 11/Head 3 Symmetry']),
            get_interpolation(data['Layer 11/Head 4 Symmetry']),
            get_interpolation(data['Layer 11/Head 5 Symmetry']),
            get_interpolation(data['Layer 11/Head 6 Symmetry']),
            get_interpolation(data['Layer 11/Head 7 Symmetry']),
            get_interpolation(data['Layer 11/Head 8 Symmetry']),
            get_interpolation(data['Layer 11/Head 9 Symmetry']),
            get_interpolation(data['Layer 11/Head 10 Symmetry']),
            get_interpolation(data['Layer 11/Head 11 Symmetry']),    
            get_interpolation(data['train/loss'])]
            # get_interpolation(data['reg_loss']),
            # get_interpolation(data['total_loss'])]
    
    return list

# %%
if os.path.isfile('../../_data/pascal-data/symmetry-scores/BERT-symmetry.pkl'):
    with open('../../_data/pascal-data/symmetry-scores/BERT-symmetry.pkl', 'rb') as file:
        models = pickle.load(file)
else: models = {}

# %%
'BERT small'

model = 'history_bert-encoder-jigsaw.csv'
data = pd.read_csv(path + model, 
                       encoding='UTF-8', 
                       delimiter=',')  
models['bert-encoder-jigsaw'] = save_data(data)

model = 'history_bert-encoder-wikipedia.csv'
data = pd.read_csv(path + model, 
                       encoding='UTF-8', 
                       delimiter=',')  
models['bert-encoder-wikipedia'] = save_data(data)

model = 'history_bert-encoder-red_pajama.csv'
data = pd.read_csv(path + model, 
                       encoding='UTF-8', 
                       delimiter=',')  
models['bert-encoder-red_pajama'] = save_data(data)

'--------------'

model = 'history_bert-decoder-jigsaw.csv'
data = pd.read_csv(path + model, 
                       encoding='UTF-8', 
                       delimiter=',')  
models['bert-decoder-jigsaw'] = save_data(data)

model = 'history_bert-decoder-wikipedia.csv'
data = pd.read_csv(path + model, 
                       encoding='UTF-8', 
                       delimiter=',')  
models['bert-decoder-wikipedia'] = save_data(data)

model = 'history_bert-decoder-red_pajama.csv'
data = pd.read_csv(path + model, 
                       encoding='UTF-8', 
                       delimiter=',')  
models['bert-decoder-red_pajama'] = save_data(data)

# %%
model = 'history_bert-no_bias-encoder-jigsaw.csv'
data = pd.read_csv(path + model, 
                       encoding='UTF-8', 
                       delimiter=',')  
models['bert-no_bias-encoder-jigsaw'] = save_data(data)

model = 'history_bert-no_bias-encoder-wikipedia.csv'
data = pd.read_csv(path + model, 
                       encoding='UTF-8', 
                       delimiter=',')  
models['bert-no_bias-encoder-wikipedia'] = save_data(data)

model = 'history_bert-no_bias-encoder-red_pajama.csv'
data = pd.read_csv(path + model, 
                       encoding='UTF-8', 
                       delimiter=',')  
models['bert-no_bias-encoder-red_pajama'] = save_data(data)

'--------------'

model = 'history_bert-no_bias-decoder-jigsaw.csv'
data = pd.read_csv(path + model, 
                       encoding='UTF-8', 
                       delimiter=',')  
models['bert-no_bias-decoder-jigsaw'] = save_data(data)

model = 'history_bert-no_bias-decoder-wikipedia.csv'
data = pd.read_csv(path + model, 
                       encoding='UTF-8', 
                       delimiter=',')  
models['bert-no_bias-decoder-wikipedia'] = save_data(data)

model = 'history_bert-no_bias-decoder-red_pajama.csv'
data = pd.read_csv(path + model, 
                       encoding='UTF-8', 
                       delimiter=',')  
models['bert-no_bias-decoder-red_pajama'] = save_data(data)

# %%
with open('../../_data/pascal-data/symmetry-scores/BERT-symmetry.pkl', 'wb') as file:
    pickle.dump(models, file)
