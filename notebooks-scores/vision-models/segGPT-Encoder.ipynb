# %%
import pickle

from transformers import AutoModel, AutoConfig
from utils.funs import create_dict
from utils.scores import get_scores

# %%
model_name = 'BAAI/seggpt-vit-large'
config = AutoConfig.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
print(model)
# Out:
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# 2024-12-29 16:07:44.975499: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors:   0%|          | 0.00/1.48G [00:00<?, ?B/s]
# SegGptModel(
#   (embeddings): SegGptEmbeddings(
#     (patch_embeddings): SegGptPatchEmbeddings(
#       (projection): Conv2d(3, 1024, kernel_size=(16, 16), stride=(16, 16))
#     )
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): SegGptEncoder(
#     (layers): ModuleList(
#       (0): SegGptLayer(
#         (attention): SegGptAttention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#         )
# ...

# %%
models, dir = create_dict('vision-models', 'segGPT.pkl')

path = ["encoder.layers[", 
        "].attention.qkv.weight"]

# %%
raise AttributeError("How to deal with qkv matrices?")

# %%
model_name = 'BAAI/seggpt-vit-large'
config = AutoConfig.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
models = get_scores(models,
                    model_name, model, config,
                    path, download_model = True)

# %%
'save'
with open(dir, 'wb') as file:
    pickle.dump(models, file)
