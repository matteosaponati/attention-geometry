# %%
import pickle

from transformers import AutoModel, AutoConfig
from utils.funs import create_dict
from utils.scores import get_scores

# %%
model_name = 'microsoft/swinv2-tiny-patch4-window16-256'
config = AutoConfig.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
print(model)
# Out:
# config.json:   0%|          | 0.00/69.9k [00:00<?, ?B/s]
# 2024-12-29 15:43:08.325701: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# pytorch_model.bin:   0%|          | 0.00/113M [00:00<?, ?B/s]
# Swinv2Model(
#   (embeddings): Swinv2Embeddings(
#     (patch_embeddings): Swinv2PatchEmbeddings(
#       (projection): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#     )
#     (norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (encoder): Swinv2Encoder(
#     (layers): ModuleList(
#       (0): Swinv2Stage(
#         (blocks): ModuleList(
#           (0): Swinv2Layer(
#             (attention): Swinv2Attention(
#               (self): Swinv2SelfAttention(
# ...

# %%
models, dir = create_dict('vision-models', 'SWINv2.pkl')

path = ["encoder.layers[", 
        "].blocks[", 
        "].attention.self.query.weight", 
        "].attention.self.key.weight"]

# %%
print(config.num_attention_heads)
raise NotImplementedError("This kind of config raises an error in the get score function")
# Out:
# [3, 6, 12, 24]

# %%
model_name = 'microsoft/swinv2-tiny-patch4-window16-256'
config = AutoConfig.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
models = get_scores(models,
                    model_name, model, config,
                    path, download_model = True)

model_name = 'microsoft/swinv2-base-patch4-window16-256'
config = AutoConfig.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
models = get_scores(models,
                    model_name, model, config,
                    path, download_model = True)

model_name = 'microsoft/swinv2-large-patch4-window12to16-192to256-22kto1k-ft'
config = AutoConfig.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)
models = get_scores(models,
                    model_name, model, config,
                    path, download_model = True)
# Out:
#  25% processing layer 1/4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 config = AutoConfig.from_pretrained(model_name)
#       3 model = AutoModel.from_pretrained(model_name)
# ----> 4 models = get_scores(models,
#       5                     model_name, model, config,
#       6                     path, download_model = True)
#       8 model_name = 'microsoft/swinv2-base-patch4-window16-256'
#       9 config = AutoConfig.from_pretrained(model_name)
#
# File ~/Documents/Projects/attention-geometry/utils/scores.py:42, in get_scores(models, model_name, model, config, path, custom_checkpoint, download_model, attn_type)
#      40     M = get_M_checkpoints(model, path, layer)
#      41 else:
# ---> 42     if download_model == True: M = get_M_fullmodel(model, config, path, layer, attn_type)
# ...

# %%
'save'
with open(dir, 'wb') as file:
    pickle.dump(models, file)
