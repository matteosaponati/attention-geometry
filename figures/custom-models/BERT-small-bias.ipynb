# %%
import pickle
import numpy as np
from scipy.stats import sem
import matplotlib.pyplot as plt

# %%
## BERT base reference

## BERT base reference
with open('../../_data/fig_scores/BERT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)

BERT_small_mean = models['BERTsmall'][-2].mean()

# %%
plt.figure(figsize=(4,4))

# bert-small-small 
with open('../../_data/pascal-data/symmetry-scores/BERT-small-symmetry.pkl', 'rb') as file:
    models = pickle.load(file)

step = models['bert-small-encoder-jigsaw'][0]
symmetry_scores = models['bert-small-encoder-jigsaw'][2]
var_scores = models['bert-small-encoder-jigsaw'][6]
plt.plot(step, symmetry_scores, 
         color = 'darkblue', linestyle = 'dashed')
plt.fill_between(step, symmetry_scores - var_scores,
                 symmetry_scores + var_scores,
                 color = 'darkblue', alpha = .3)

step = models['bert-small-encoder-wikipedia'][0]
symmetry_scores = models['bert-small-encoder-wikipedia'][2]
var_scores = models['bert-small-encoder-wikipedia'][6]
plt.plot(step, symmetry_scores, 
         color = 'blue', linestyle = 'dashed')
plt.fill_between(step, symmetry_scores - var_scores,
                 symmetry_scores + var_scores,
                 color = 'blue', alpha = .3)

step = models['bert-small-encoder-red_pajama'][0]
symmetry_scores = models['bert-small-encoder-red_pajama'][2]
var_scores = models['bert-small-encoder-red_pajama'][6]
plt.plot(step, symmetry_scores, 
         color = 'slateblue', linestyle = 'dashed')
plt.fill_between(step, symmetry_scores - var_scores,
                 symmetry_scores + var_scores,
                 color = 'slateblue', alpha = .3)

step = models['bert-small-no_bias-encoder-jigsaw'][0]
symmetry_scores = models['bert-small-no_bias-encoder-jigsaw'][2]
var_scores = models['bert-small-no_bias-encoder-jigsaw'][6]
plt.plot(step, symmetry_scores, 
         color = 'darkblue', label = 'jigsaw')
plt.fill_between(step, symmetry_scores - var_scores,
                 symmetry_scores + var_scores,
                 color = 'darkblue', alpha = .3)

step = models['bert-small-no_bias-encoder-wikipedia'][0]
symmetry_scores = models['bert-small-no_bias-encoder-wikipedia'][2]
var_scores = models['bert-small-no_bias-encoder-wikipedia'][6]
plt.plot(step, symmetry_scores, 
         color = 'blue', label = 'wikipedia')
plt.fill_between(step, symmetry_scores - var_scores,
                 symmetry_scores + var_scores,
                 color = 'blue', alpha = .3)

step = models['bert-small-no_bias-encoder-red_pajama'][0]
symmetry_scores = models['bert-small-no_bias-encoder-red_pajama'][2]
var_scores = models['bert-small-no_bias-encoder-red_pajama'][6]
plt.plot(step, symmetry_scores, 
         color = 'slateblue', label = 'red-pajama')
plt.fill_between(step, symmetry_scores - var_scores,
                 symmetry_scores + var_scores,
                 color = 'slateblue', alpha = .3)

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.ylabel('scores')
plt.xlabel('epochs')
plt.title('encoder-only (4 l, 8 h)')
plt.ylim(0,1)

plt.axhline(y = .5,color='k')
# plt.axhline(y = BERT_small_mean,color='lightblue',linestyle='dashed', label = 'bert-small-mean')

plt.legend()

# %%
plt.figure(figsize=(4,4))

step = models['bert-small-encoder-jigsaw'][0]
loss = models['bert-small-encoder-jigsaw'][-1]
plt.plot(step, loss, 
         color = 'darkblue', label = 'encoder-jigsaw')

step = models['bert-small-encoder-wikipedia'][0]
loss = models['bert-small-encoder-wikipedia'][-1]
plt.plot(step, loss, 
         color = 'blue', label = 'encoder-wiki')

step = models['bert-small-encoder-red_pajama'][0]
loss = models['bert-small-encoder-red_pajama'][-1]
plt.plot(step, loss, 
         color = 'slateblue', label = 'encoder-red_pajama')

step = models['bert-small-no_bias-encoder-jigsaw'][0]
loss = models['bert-small-no_bias-encoder-jigsaw'][-1]
plt.plot(step, loss, 
         color = 'darkblue', linestyle = 'dashed')

step = models['bert-small-no_bias-encoder-wikipedia'][0]
loss = models['bert-small-no_bias-encoder-wikipedia'][-1]
plt.plot(step, loss, 
         color = 'blue', linestyle = 'dashed')

step = models['bert-small-no_bias-encoder-red_pajama'][0]
loss = models['bert-small-no_bias-encoder-red_pajama'][-1]
plt.plot(step, loss, 
         color = 'slateblue', linestyle = 'dashed')

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.ylabel('train loss [masked]')
plt.xlabel('epochs')
plt.title('encoder-only (4 l, 8 h)')
# plt.legend()
# Out:
# Text(0.5, 1.0, 'encoder-only (4 l, 8 h)')

# %%
plt.figure(figsize=(4,4))

step = models['bert-small-decoder-jigsaw'][0]
symmetry_scores = models['bert-small-decoder-jigsaw'][2]
var_scores = models['bert-small-decoder-jigsaw'][6]
plt.plot(step, symmetry_scores, 
         color = 'palevioletred', linestyle = 'dashed')
plt.fill_between(step, symmetry_scores - var_scores,
                 symmetry_scores + var_scores,
                 color = 'palevioletred', alpha = .3)

step = models['bert-small-decoder-wikipedia'][0]
symmetry_scores = models['bert-small-decoder-wikipedia'][2]
var_scores = models['bert-small-decoder-wikipedia'][6]
plt.plot(step, symmetry_scores, 
         color = 'darkmagenta', linestyle = 'dashed')
plt.fill_between(step, symmetry_scores - var_scores,
                 symmetry_scores + var_scores,
                 color = 'darkmagenta', alpha = .3)

step = models['bert-small-decoder-red_pajama'][0]
symmetry_scores = models['bert-small-decoder-red_pajama'][2]
var_scores = models['bert-small-decoder-red_pajama'][6]
plt.plot(step, symmetry_scores, 
         color = 'hotpink', linestyle = 'dashed')
plt.fill_between(step, symmetry_scores - var_scores,
                 symmetry_scores + var_scores,
                 color = 'hotpink', alpha = .3)

step = models['bert-small-no_bias-decoder-jigsaw'][0]
symmetry_scores = models['bert-small-no_bias-decoder-jigsaw'][2]
var_scores = models['bert-small-no_bias-decoder-jigsaw'][6]
plt.plot(step, symmetry_scores, 
         color = 'palevioletred', label = 'jigsaw')
plt.fill_between(step, symmetry_scores - var_scores,
                 symmetry_scores + var_scores,
                 color = 'palevioletred', alpha = .3)

step = models['bert-small-no_bias-decoder-wikipedia'][0]
symmetry_scores = models['bert-small-no_bias-decoder-wikipedia'][2]
var_scores = models['bert-small-no_bias-decoder-wikipedia'][6]
plt.plot(step, symmetry_scores, 
         color = 'darkmagenta', label = 'wikipedia')
plt.fill_between(step, symmetry_scores - var_scores,
                 symmetry_scores + var_scores,
                 color = 'darkmagenta', alpha = .3)

step = models['bert-small-no_bias-decoder-red_pajama'][0]
symmetry_scores = models['bert-small-no_bias-decoder-red_pajama'][2]
var_scores = models['bert-small-no_bias-decoder-red_pajama'][6]
plt.plot(step, symmetry_scores, 
         color = 'hotpink', label = 'red-pajama')
plt.fill_between(step, symmetry_scores - var_scores,
                 symmetry_scores + var_scores,
                 color = 'hotpink', alpha = .3)

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.ylabel('scores')
plt.xlabel('epochs')
plt.title('decoder-only (4 l, 8 h)')
plt.ylim(0,1)

plt.axhline(y = .5,color='k')

plt.legend()

# %%
plt.figure(figsize=(4,4))

step = models['bert-small-decoder-jigsaw'][0]
loss = models['bert-small-decoder-jigsaw'][-1]
plt.plot(step, loss, 
         color = 'palevioletred', label = 'decoder-jigsaw')

step = models['bert-small-decoder-wikipedia'][0]
loss = models['bert-small-decoder-wikipedia'][-1]
plt.plot(step, loss, 
         color = 'darkmagenta', label = 'decoder-wiki')

step = models['bert-small-decoder-red_pajama'][0]
loss = models['bert-small-decoder-red_pajama'][-1]
plt.plot(step, loss, 
         color = 'hotpink', label = 'decoder-red_pajama')

step = models['bert-small-no_bias-decoder-jigsaw'][0]
loss = models['bert-small-no_bias-decoder-jigsaw'][-1]
plt.plot(step, loss, 
         color = 'palevioletred', linestyle = 'dashed')

step = models['bert-small-no_bias-decoder-wikipedia'][0]
loss = models['bert-small-no_bias-decoder-wikipedia'][-1]
plt.plot(step, loss, 
         color = 'darkmagenta', linestyle = 'dashed')

step = models['bert-small-no_bias-decoder-red_pajama'][0]
loss = models['bert-small-no_bias-decoder-red_pajama'][-1]
plt.plot(step, loss, 
         color = 'hotpink', linestyle = 'dashed')

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.ylabel('train loss [masked]')
plt.xlabel('epochs')
plt.title('decoder-only (4 l, 8 h)')
# plt.legend()
# Out:
# Text(0.5, 1.0, 'decoder-only (4 l, 8 h)')
