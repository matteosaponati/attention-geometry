# %%
import pickle
import numpy as np
from scipy.stats import sem
import matplotlib.pyplot as plt

# %%
"""
Visualization of level of symmetry between different models 
(across layers and heads)
"""

plt.figure(figsize=(12,4))

## BERT models
plt.subplot(1,3,1)

# get scores for BERT models calculated on each head
with open('../_data/fig_scores/BERT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='darkblue',alpha=.01)
    plt.scatter(i,(SList[i].flatten()).mean(),color='darkblue')

# get scores for BERT models calculated on the whole M matrix
with open('../_data/fig_scores/BERT-query-key-full.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='darkblue',alpha=.1,facecolors='none')
    plt.scatter(i,(SList[i].flatten()).mean(),color='darkblue',facecolors='none')

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.title('BERT models')
plt.ylabel('scores')
plt.xticks(np.arange(len(names)),names)
plt.xticks(rotation=50)
plt.ylim(0,1)
plt.axhline(y=.5,color='k',linestyle='dashed')

## ROBERTA
plt.subplot(1,3,2)

with open('../_data/fig_scores/ROBERTA-query-key.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='blue',alpha=.01)
    plt.scatter(i,(SList[i].flatten()).mean(),color='blue')

# get scores for BERT models calculated on the whole M matrix
with open('../_data/fig_scores/ROBERTA-query-key-full.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='blue',alpha=.1,facecolors='none')
    plt.scatter(i,(SList[i].flatten()).mean(),color='blue',facecolors='none')

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.title('ROBERTA models')
plt.ylabel('scores')
plt.xticks(np.arange(len(names)),names)
plt.xticks(rotation=50)
plt.ylim(0,1)
plt.axhline(y=.5,color='k',linestyle='dashed')

## ALBERT
plt.subplot(1,3,3)

with open('../_data/fig_scores/ALBERT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='mediumslateblue',alpha=.01)
    plt.scatter(i,(SList[i].flatten()).mean(),color='mediumslateblue')

# get scores for BERT models calculated on the whole M matrix
with open('../_data/fig_scores/ALBERT-query-key-full.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='mediumslateblue',alpha=.1,facecolors='none')
    plt.scatter(i,(SList[i].flatten()).mean(),color='mediumslateblue',facecolors='none')

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.title('ALBERT models')
plt.ylabel('scores')
plt.xticks(np.arange(len(names)),names)
plt.xticks(rotation=50)
plt.ylim(0,1)
plt.axhline(y=.5,color='k',linestyle='dashed')

# %%
"""
Visualization of level of symmetry between different models 
(across layers and heads)
"""

plt.figure(figsize=(15,8))

## BERT models
plt.subplot(2,3,1)

# get scores for BERT models calculated on each head
with open('../_data/fig_scores/BERT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='purple',alpha=.01)
    plt.scatter(i,(SList[i].flatten()).mean(),color='purple')

# get scores for BERT models calculated on the whole M matrix
with open('../_data/fig_scores/BERT-query-key-full.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='darkred',alpha=.01)
    plt.scatter(i,(SList[i].flatten()).mean(),color='darkred')

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.title('BERT models')
plt.ylabel('scores')
plt.xticks(np.arange(len(names)),[])
plt.ylim(0,1)
plt.axhline(y=.5,color='k',linestyle='dashed')

## ROBERTA
plt.subplot(2,3,2)

with open('../_data/fig_scores/ROBERTA-query-key.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='purple',alpha=.01)
    plt.scatter(i,(SList[i].flatten()).mean(),color='purple')

# get scores for BERT models calculated on the whole M matrix
with open('../_data/fig_scores/ROBERTA-query-key-full.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='darkred',alpha=.1)
    plt.scatter(i,(SList[i].flatten()).mean(),color='darkred')

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.title('ROBERTA models')
plt.ylabel('scores')
plt.xticks(np.arange(len(names)),[])
plt.ylim(0,1)
plt.axhline(y=.5,color='k',linestyle='dashed')

## ALBERT
plt.subplot(2,3,3)

with open('../_data/fig_scores/ALBERT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='purple',alpha=.1)
    plt.scatter(i,(SList[i].flatten()).mean(),color='purple')

# get scores for BERT models calculated on the whole M matrix
with open('../_data/fig_scores/ALBERT-query-key-full.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='darkred',alpha=.1)
    plt.scatter(i,(SList[i].flatten()).mean(),color='darkred')

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.title('ALBERT models')
plt.ylabel('scores')
plt.xticks(np.arange(len(names)),[])
plt.ylim(0,1)
plt.axhline(y=.5,color='k',linestyle='dashed')

## BERT models
plt.subplot(2,3,4)

# get scores for BERT models calculated on each head
with open('../_data/fig_scores/BERT-value-out.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='lightblue',alpha=.01)
    plt.scatter(i,(SList[i].flatten()).mean(),color='lightblue')

# get scores for BERT models calculated on the whole M matrix
with open('../_data/fig_scores/BERT-value-out-full.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='darkblue',alpha=.01)
    plt.scatter(i,(SList[i].flatten()).mean(),color='darkblue')

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.ylabel('scores')
plt.xticks(np.arange(len(names)),names)
plt.xticks(rotation=50)
plt.ylim(0,1)
plt.axhline(y=.5,color='k',linestyle='dashed')

## ROBERTA
plt.subplot(2,3,5)

with open('../_data/fig_scores/ROBERTA-value-out.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='lightblue',alpha=.01)
    plt.scatter(i,(SList[i].flatten()).mean(),color='lightblue')

# get scores for BERT models calculated on the whole M matrix
with open('../_data/fig_scores/ROBERTA-value-out-full.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='darkblue',alpha=.1)
    plt.scatter(i,(SList[i].flatten()).mean(),color='darkblue')

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.ylabel('scores')
plt.xticks(np.arange(len(names)),names)
plt.xticks(rotation=50)
plt.ylim(0,1)
plt.axhline(y=.5,color='k',linestyle='dashed')

## ALBERT
plt.subplot(2,3,6)

with open('../_data/fig_scores/ALBERT-value-out.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='lightblue',alpha=.1)
    plt.scatter(i,(SList[i].flatten()).mean(),color='lightblue')

# get scores for BERT models calculated on the whole M matrix
with open('../_data/fig_scores/ALBERT-value-out-full.pkl', 'rb') as file:
    models = pickle.load(file)

SList = [models[key][-2].flatten()**2 for key in list(models.keys())]
names = list(models.keys())

for i, model in enumerate(SList):
    
    plt.scatter(i*np.ones(SList[i].size),SList[i],color='darkblue',alpha=.1)
    plt.scatter(i,(SList[i].flatten()).mean(),color='darkblue')

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.ylabel('scores')
plt.xticks(np.arange(len(names)),names)
plt.xticks(rotation=50)
plt.ylim(0,1)
plt.axhline(y=.5,color='k',linestyle='dashed')
