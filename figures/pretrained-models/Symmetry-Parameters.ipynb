# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
'upload scores and features (# params, # layers, ...) for all models'

## BERT models
BERT_par = [4.4e6, 11.3e6, 29.1e6, 41.7e6, 110e6, 340e6, 340e6, 66e6]
with open('../../_data/fig_scores/BERT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)
BERT_score = [(models[key][-2].flatten().flatten()**2).mean() for key in list(models.keys())]
BERT_score_h = [models[key][-2].flatten()**2 for key in list(models.keys())]
BERT_layers = [models[key][0] for key in list(models.keys())]
BERT_d_emb = [models[key][1] for key in list(models.keys())]

## ROBERT models
ROBERTA_par = [125e6, 355e6, 82.2e6]
with open('../../_data/fig_scores/ROBERTA-query-key.pkl', 'rb') as file:
    models = pickle.load(file)
ROBERTA_score = [(models[key][-2].flatten().flatten()**2).mean() for key in list(models.keys())]
ROBERTA_score_h = [models[key][-2].flatten()**2 for key in list(models.keys())]
ROBERTA_layers = [models[key][0] for key in list(models.keys())]
ROBERTA_d_emb = [models[key][1] for key in list(models.keys())]

## ALBERT models
ALBERT_par = [11e6, 17e6, 58e6, 223e6]
with open('../../_data/fig_scores/ALBERT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)
ALBERT_score = [(models[key][-2].flatten().flatten()**2).mean() for key in list(models.keys())]
ALBERT_score_h = [models[key][-2].flatten()**2 for key in list(models.keys())]
ALBERT_layers = [models[key][0] for key in list(models.keys())]
ALBERT_d_emb = [models[key][1] for key in list(models.keys())]

## GPT models
GPT_par = [110e6, 117e6, 345e6, 774e6, 1558e6, 82e6]
with open('../../_data/fig_scores/GPT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)
GPT_score = [(models[key][-2].flatten().flatten()**2).mean() for key in list(models.keys())]
GPT_score_h = [models[key][-2].flatten()**2 for key in list(models.keys())]
GPT_layers = [models[key][0] for key in list(models.keys())]
GPT_d_emb = [models[key][1] for key in list(models.keys())]

## TinyGPT models
TinyGPT_par = [1e6, 3e6, 8e6, 21e6, 28e6]
with open('../../_data/fig_scores/TinyGPT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)
TinyGPT_score = [(models[key][-2].flatten().flatten()**2).mean() for key in list(models.keys())]
TinyGPT_score_h = [models[key][-2].flatten()**2 for key in list(models.keys())]
TinyGPT_layers = [models[key][0] for key in list(models.keys())]
TinyGPT_d_emb = [models[key][1] for key in list(models.keys())]

## OPT models
OPT_par = [125e6, 350e6, 1300e6, 2700e6, 67008e6, 13000e6]
with open('../../_data/fig_scores/OPT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)
OPT_score = [(models[key][-2].flatten().flatten()**2).mean() for key in list(models.keys())]
OPT_score_h = [models[key][-2].flatten()**2 for key in list(models.keys())]
OPT_layers = [models[key][0] for key in list(models.keys())]
OPT_d_emb = [models[key][1] for key in list(models.keys())]

## T5 models
T5Encoder_par = [60.5e6, 223e6, 738e6, 2850e6]
with open('../../_data/fig_scores/T5Encoder-query-key.pkl', 'rb') as file:
    models = pickle.load(file)
T5Encoder_score = [(models[key][-2].flatten().flatten()**2).mean() for key in list(models.keys())]
T5ENcoder_score_h = [models[key][-2].flatten()**2 for key in list(models.keys())]
T5Encoder_layers = [models[key][0] for key in list(models.keys())]
T5Encoder_d_emb = [models[key][1] for key in list(models.keys())]

T5Decoder_par = [60.5e6, 223e6, 738e6, 2850e6]
with open('../../_data/fig_scores/T5Decoder-query-key.pkl', 'rb') as file:
    models = pickle.load(file)
T5Decoder_score = [(models[key][-2].flatten().flatten()**2).mean() for key in list(models.keys())]
T5Decoder_score_h = [models[key][-2].flatten()**2 for key in list(models.keys())]
T5Decoder_layers = [models[key][0] for key in list(models.keys())]
T5Decoder_d_emb = [models[key][1] for key in list(models.keys())]

## GEMMA models
GEMMA_par = [2000e6, 7000e6]
with open('../../_data/fig_scores/GEMMA-query-key.pkl', 'rb') as file:
    models = pickle.load(file)
GEMMA_score = [(models[key][-2].flatten().flatten()**2).mean() for key in list(models.keys())]
GEMMA_score_h = [models[key][-2].flatten()**2 for key in list(models.keys())]
GEMMA_layers = [models[key][0] for key in list(models.keys())]
GEMMA_d_emb = [models[key][1] for key in list(models.keys())]

GEMMA_par = [2000e6, 7000e6]
with open('../../_data/fig_scores/GEMMA1-query-key.pkl', 'rb') as file:
    models = pickle.load(file)
GEMMA1_score = [(models[key][-2].flatten().flatten()**2).mean() for key in list(models.keys())]
GEMMA1_score_h = [models[key][-2].flatten()**2 for key in list(models.keys())]
GEMMA1_layers = [models[key][0] for key in list(models.keys())]
GEMMA1_d_emb = [models[key][1] for key in list(models.keys())]

## LLAMA models
LLAMA_par = [7000e6, 13000e6]
with open('../../_data/fig_scores/LLAMA2-query-key.pkl', 'rb') as file:
    models = pickle.load(file)
LLAMA_score = [(models[key][-2].flatten().flatten()**2).mean() for key in list(models.keys())]
LLAMA_score_h = [models[key][-2].flatten()**2 for key in list(models.keys())]
LLAMA_layers = [models[key][0] for key in list(models.keys())]
LLAMA_d_emb = [models[key][1] for key in list(models.keys())]

## MISTRAL models
MISTRAL_par = [7000e6, 7000e6, 7000e6]
with open('../../_data/fig_scores/MISTRAL-query-key.pkl', 'rb') as file:
    models = pickle.load(file)
MISTRAL_score = [(models[key][-2].flatten().flatten()**2).mean() for key in list(models.keys())]
MISTRAL_score_h = [models[key][-2].flatten()**2 for key in list(models.keys())]
MISTRAL_layers = [models[key][0] for key in list(models.keys())]
MISTRAL_d_emb = [models[key][1] for key in list(models.keys())]

# %%
"""
mean symmetry scores (across layers and heads) as a function of total # parameters
"""

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)

## encoder-only models
plt.scatter(BERT_par,BERT_score, color='darkblue', label='BERT')
plt.scatter(ROBERTA_par,ROBERTA_score,color='blue', label='ROBERTA')
plt.scatter(ALBERT_par,ALBERT_score,color='mediumslateblue', label='ALBERT', facecolors='none')
## encoder-decoder models
# plt.scatter(T5Encoder_par,T5Encoder_score,color='plum', label='T5 (encoder)')

plt.title('encoder-only models')
plt.axhline(y=.5,linestyle='dashed',color='k')
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.xscale('log')
plt.legend()
plt.ylim(0,1)
plt.ylabel('symmetry score (mean)')
plt.xlabel('# parameters')
plt.xlim(1e5,10e10)

plt.subplot(1,2,2)

## decoder-only models
plt.scatter(GPT_par,GPT_score,color='palevioletred', label='GPT')
plt.scatter(OPT_par,OPT_score,color='darkmagenta', label='OPT')
plt.scatter(TinyGPT_par,TinyGPT_score,color='hotpink', label='TinyGPT')
## encoder-decoder models
# plt.scatter(T5Decoder_par,T5Decoder_score,color='plum', label='T5 (decoder)')
## decoder-only models (with quite some other fine-tuning)
plt.scatter(GEMMA_par,GEMMA1_score,color='crimson', label='Gemma', facecolors='none')
plt.scatter(GEMMA_par,GEMMA_score,color='crimson', facecolors='none')
plt.scatter(LLAMA_par,LLAMA_score,color='magenta', label='Llama 2', facecolors='none')
plt.scatter(MISTRAL_par,MISTRAL_score,color='purple', label='Mistral', facecolors='none')

plt.title('decoder-only models')
plt.axhline(y=.5,linestyle='dashed',color='k')
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.xscale('log')
plt.legend()
plt.ylim(0,1)
plt.ylabel('symmetry score (mean)')
plt.xlabel('# parameters')
plt.xlim(1e5,10e10)
# Out:
# (100000.0, 100000000000.0)
