# %%
import pickle
import numpy as np
from scipy.stats import sem, iqr
import matplotlib.pyplot as plt

# %%
# get query-key scores for BERT models calculated on each head
with open('../../_data/fig_scores/BERT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)

with open('../../_data/fig_scores/BERT-query-key-full.pkl', 'rb') as file:
    models_full = pickle.load(file)

names = list(models.keys())

plt.figure(figsize=(5,6 * len(names)))

for i, name in enumerate(names):
    
    plt.subplot(len(names),1,i+1)

    model = models[name][-2]**2
    model_full = models_full[name][-2]**2

    plt.scatter(np.arange(model_full.shape[0]),model_full,color='mediumvioletred')

    plt.plot(np.arange(model.shape[0]),np.median(model,axis=1),color='purple')
    plt.fill_between(np.arange(model.shape[0]),
                 np.median(model,axis=1)+ iqr(model,axis=1),
                 np.median(model,axis=1)- iqr(model,axis=1),
                 color='purple',alpha=.3)
    
    for layer in range(model.shape[0]):
        plt.scatter(layer*np.ones(model.shape[1]),model[layer,:],color='purple',alpha=.1)

    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.title(name)
    plt.ylabel('scores')
    plt.xlabel('layers')
    plt.ylim(0,1)
    plt.axhline(y=.5,color='k',linestyle='dashed')

# %%
# get value-out scores for BERT models calculated on each head

with open('../../_data/fig_scores/BERT-value-out.pkl', 'rb') as file:
    models = pickle.load(file)

with open('../../_data/fig_scores/BERT-value-out-full.pkl', 'rb') as file:
    models_full = pickle.load(file)

names = list(models.keys())

plt.figure(figsize=(5,6 * len(names)))

for i, name in enumerate(names):
    
    plt.subplot(len(names),1,i+1)

    model = models[name][-2]**2
    model_full = models_full[name][-2]**2

    plt.scatter(np.arange(model_full.shape[0]),model_full,color='darkblue')

    plt.plot(np.arange(model.shape[0]),np.median(model,axis=1),color='blue')
    plt.fill_between(np.arange(model.shape[0]),
                 np.median(model,axis=1)+ iqr(model,axis=1),
                 np.median(model,axis=1)- iqr(model,axis=1),
                 color='lightblue',alpha=.3)
    
    for layer in range(model.shape[0]):
        plt.scatter(layer*np.ones(model.shape[1]),model[layer,:],color='blue',alpha=.1)

    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.title(name)
    plt.ylabel('scores')
    plt.xlabel('layers')
    plt.ylim(0,1)
    plt.axhline(y=.5,color='k',linestyle='dashed')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 18
#      15 plt.subplot(len(names),1,i+1)
#      17 model = models[name][-2]**2
# ---> 18 model_full = models_full[name][-2]**2
#      20 plt.scatter(np.arange(model_full.shape[0]),model_full,color='darkblue')
#      22 plt.plot(np.arange(model.shape[0]),np.median(model,axis=1),color='blue')
#
# KeyError: 'BERTlarge_mask'

# %%
# get query-key scores for ROBERTA models calculated on each head

with open('../../_data/fig_scores/ROBERTA-query-key.pkl', 'rb') as file:
    models = pickle.load(file)

with open('../../_data/fig_scores/ROBERTA-query-key-full.pkl', 'rb') as file:
    models_full = pickle.load(file)

names = list(models.keys())

plt.figure(figsize=(5,6 * len(names)))

for i, name in enumerate(names):
    
    plt.subplot(len(names),1,i+1)

    model = models[name][-2]**2
    model_full = models_full[name][-2]**2

    plt.scatter(np.arange(model_full.shape[0]),model_full,color='mediumvioletred')

    plt.plot(np.arange(model.shape[0]),np.median(model,axis=1),color='purple')
    plt.fill_between(np.arange(model.shape[0]),
                 np.median(model,axis=1)+ iqr(model,axis=1),
                 np.median(model,axis=1)- iqr(model,axis=1),
                 color='purple',alpha=.3)
    
    for layer in range(model.shape[0]):
        plt.scatter(layer*np.ones(model.shape[1]),model[layer,:],color='purple',alpha=.1)

    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.title(name)
    plt.ylabel('scores')
    plt.xlabel('layers')
    plt.ylim(0,1)
    plt.axhline(y=.5,color='k',linestyle='dashed')

# %%
with open('../../_data/fig_scores/ROBERTA-value-out.pkl', 'rb') as file:
    models = pickle.load(file)

with open('../../_data/fig_scores/ROBERTA-value-out-full.pkl', 'rb') as file:
    models_full = pickle.load(file)

names = list(models.keys())

plt.figure(figsize=(5,6 * len(names)))

for i, name in enumerate(names):
    
    plt.subplot(len(names),1,i+1)

    model = models[name][-2]**2
    model_full = models_full[name][-2]**2

    plt.scatter(np.arange(model_full.shape[0]),model_full,color='darkblue')

    plt.plot(np.arange(model.shape[0]),np.median(model,axis=1),color='blue')
    plt.fill_between(np.arange(model.shape[0]),
                 np.median(model,axis=1)+ iqr(model,axis=1),
                 np.median(model,axis=1)- iqr(model,axis=1),
                 color='lightblue',alpha=.3)
    
    for layer in range(model.shape[0]):
        plt.scatter(layer*np.ones(model.shape[1]),model[layer,:],color='blue',alpha=.1)

    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.title(name)
    plt.ylabel('scores')
    plt.xlabel('layers')
    plt.ylim(0,1)
    plt.axhline(y=.5,color='k',linestyle='dashed')

# %%
# get query-key scores for ALBERT models calculated on each head

with open('../../_data/fig_scores/ALBERT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)

with open('../../_data/fig_scores/ALBERT-query-key-full.pkl', 'rb') as file:
    models_full = pickle.load(file)

names = list(models.keys())

plt.figure(figsize=(5,6 * len(names)))

for i, name in enumerate(names):
    
    plt.subplot(len(names),1,i+1)

    model = models[name][-2]**2
    model_full = models_full[name][-2]**2

    plt.scatter(np.arange(model_full.shape[0]),model_full,color='mediumvioletred')

    plt.plot(np.arange(model.shape[0]),np.median(model,axis=1),color='purple')
    plt.fill_between(np.arange(model.shape[0]),
                 np.median(model,axis=1)+ iqr(model,axis=1),
                 np.median(model,axis=1)- iqr(model,axis=1),
                 color='purple',alpha=.3)
    
    for layer in range(model.shape[0]):
        plt.scatter(layer*np.ones(model.shape[1]),model[layer,:],color='purple',alpha=.1)

    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.title(name)
    plt.ylabel('scores')
    plt.xlabel('layers')
    plt.ylim(0,1)
    plt.axhline(y=.5,color='k',linestyle='dashed')

# %%
# get value-out scores for ALBERT models calculated on each head

with open('../../_data/fig_scores/ALBERT-value-out.pkl', 'rb') as file:
    models = pickle.load(file)

names = list(models.keys())

plt.figure(figsize=(5,6 * len(names)))

for i, name in enumerate(names):
    
    plt.subplot(len(names),1,i+1)

    model = models[name][-2]**2

    plt.plot(np.arange(model.shape[0]),np.median(model,axis=1),color='purple')
    plt.fill_between(np.arange(model.shape[0]),
                 np.median(model,axis=1)+ iqr(model,axis=1),
                 np.median(model,axis=1)- iqr(model,axis=1),
                 color='purple',alpha=.3)
    
    for layer in range(model.shape[0]):
        plt.scatter(layer*np.ones(model.shape[1]),model[layer,:],color='purple',alpha=.1)

    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.title(name)
    plt.ylabel('scores')
    plt.xlabel('layers')
    plt.ylim(0,1)
    plt.axhline(y=.5,color='k',linestyle='dashed')

# %%
# get query-key scores for GPT models calculated on each head

with open('../../_data/fig_scores/GPT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)

names = list(models.keys())

plt.figure(figsize=(5,6 * len(names)))

for i, name in enumerate(names):
    
    plt.subplot(len(names),1,i+1)

    model = models[name][-2]**2

    plt.plot(np.arange(model.shape[0]),np.median(model,axis=1),color='purple')
    plt.fill_between(np.arange(model.shape[0]),
                 np.median(model,axis=1)+ iqr(model,axis=1),
                 np.median(model,axis=1)- iqr(model,axis=1),
                 color='purple',alpha=.3)
    
    for layer in range(model.shape[0]):
        plt.scatter(layer*np.ones(model.shape[1]),model[layer,:],color='purple',alpha=.1)

    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.title(name)
    plt.ylabel('scores')
    plt.xlabel('layers')
    plt.ylim(0,1)
    plt.axhline(y=.5,color='k',linestyle='dashed')

# %%
# get value-out scores for GPT models calculated on each head

with open('../../_data/fig_scores/GPT-value-out.pkl', 'rb') as file:
    models = pickle.load(file)

names = list(models.keys())

plt.figure(figsize=(5,6 * len(names)))

for i, name in enumerate(names):
    
    plt.subplot(len(names),1,i+1)

    model = models[name][-2]**2

    plt.plot(np.arange(model.shape[0]),np.median(model,axis=1),color='purple')
    plt.fill_between(np.arange(model.shape[0]),
                 np.median(model,axis=1)+ iqr(model,axis=1),
                 np.median(model,axis=1)- iqr(model,axis=1),
                 color='purple',alpha=.3)
    
    for layer in range(model.shape[0]):
        plt.scatter(layer*np.ones(model.shape[1]),model[layer,:],color='purple',alpha=.1)

    plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
    plt.title(name)
    plt.ylabel('scores')
    plt.xlabel('layers')
    plt.ylim(0,1)
    plt.axhline(y=.5,color='k',linestyle='dashed')

# %%
with open('../../_data/fig_scores/BERT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)

BERTlarge = models['BERTlarge'][-2]**2

with open('../../_data/fig_scores/BERT-query-key-full.pkl', 'rb') as file:
    models = pickle.load(file)

BERTlarge_full = models['BERTlarge'][-2]**2

with open('../../_data/fig_scores/GPT-query-key.pkl', 'rb') as file:
    models = pickle.load(file)

GPT2 = models['GPT2'][-2]**2

with open('../../_data/fig_scores/GPT-query-key-full.pkl', 'rb') as file:
    models = pickle.load(file)

GPT2_full = models['GPT2'][-2]**2

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)

plt.scatter(np.arange(BERTlarge_full.shape[0]),BERTlarge_full,color='black')

plt.plot(np.arange(BERTlarge.shape[0]),np.median(BERTlarge,axis=1),color='purple')
plt.fill_between(np.arange(BERTlarge.shape[0]),
                 np.median(BERTlarge,axis=1)+ iqr(BERTlarge,axis=1),
                 np.median(BERTlarge,axis=1)- iqr(BERTlarge,axis=1),
                 color='purple',alpha=.3)

for layer in range(BERTlarge.shape[0]):
    plt.scatter(layer*np.ones(BERTlarge.shape[1]),BERTlarge[layer,:],color='purple',alpha=.1)

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.title('BERT large')
plt.ylabel('scores')
plt.xlabel('layers')
plt.ylim(0,1)
plt.axhline(y=.5,color='k',linestyle='dashed')

plt.subplot(1,2,2)

plt.scatter(np.arange(GPT2_full.shape[0]),GPT2_full,color='black')

plt.plot(np.arange(GPT2.shape[0]),np.median(GPT2,axis=1),color='purple')
plt.fill_between(np.arange(GPT2.shape[0]),
                 np.median(GPT2,axis=1)+ iqr(GPT2,axis=1),
                 np.median(GPT2,axis=1)- iqr(GPT2,axis=1),
                 color='purple',alpha=.3)

for layer in range(GPT2.shape[0]):
    plt.scatter(layer*np.ones(GPT2.shape[1]),GPT2[layer,:],color='purple',alpha=.1)

plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.title('GPT-2')
plt.ylabel('scores')
plt.xlabel('layers')
plt.ylim(0,1)
plt.axhline(y=.5,color='k',linestyle='dashed')
